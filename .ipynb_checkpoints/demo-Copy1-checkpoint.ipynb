# %%
import pandas as pd
import numpy as np
import glob, os

# %%
#df = pd.concat(map(pd.read_excel, glob.glob('FILE EXCEL/*.xlsx')))

#df = pd.read_excel(r'DVDK_DL_BB_1.xlsx')
#loai = pd.read_json('loai.json')

#print(df)
#df.head(60)
#writer = pd.ExcelWriter('list.xlsx', engine='xlsxwriter')
#df.to_excel(writer, sheet_name='Loai')
#writer.save()

listfile = ["CA_NTB_1","DVDK_DL_BB_1","DVDK_DT_BB_1","DVDK_DL_BTB_1","DVDK_DL_BTB_1","DVDK_DL_NB_1","DVDK_DL_NTB_1","DVDK_DT_BB_1","DVDK_DT_BTB_1","DVDK_DT_NB_1","DVDK_DT_NTB_1","GX_DL_BB_1","GX_DL_BTB_1","GX_DL_NB_1","GX_DL_NTB_1","GX_DT_BB_1","GX_DT_BTB_1","GX_DT_NB_1","GX_DT_NTB_1","NT_DL_BB_1","NT_DL_BTB_1","NT_DL_NB_1","NT_DL_NTB_1","NT_DT_BB_1","NT_DT_BTB_1","NT_DT_NB_1","NT_DT_NTB_1"]

files = glob.glob('FILE EXCEL/*.xlsx')
df = pd.concat([pd.read_excel(fp).assign(New=os.path.basename(fp).split('.')[0]) for fp in files])

#df.head(60)
print(df)
writer = pd.ExcelWriter('list.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Loai')
writer.save()
# Out:
#                        STT                               Tên khoa học  \
# 0                      NaN                      Ngành Bacillariophyta
# 1                      NaN  Lớp Tảo Silic trung tâm - Centricophyceae
# 2                      NaN                                Bộ Discales
# 3                      NaN                        Họ Bacteriastraceae
# 4                1.               Bacteriastrum hyalinum Lauder, 1864
# ..                     ...                                        ...
# 60                     NaN                              Họ Miraciidae
# 61            39.                          Stella gracilis Dana, 1847
# 62                     NaN                               Bộ OSTRACODA
# 63                     NaN                          Họ Halocyprididae
# 64            40.                Conchoecissa imbricata (Brady, 1880)
#
#              New Unnamed: 2 Tên Tiếng Việt Tên tiếng Việt Mật độ
# 0    Tao_DL_BB_1        NaN            NaN            NaN    NaN
# 1    Tao_DL_BB_1        NaN            NaN            NaN    NaN
# 2    Tao_DL_BB_1        NaN            NaN            NaN    NaN
# 3    Tao_DL_BB_1        NaN            NaN            NaN    NaN
# 4    Tao_DL_BB_1        NaN            NaN            NaN    NaN
# ..           ...        ...            ...            ...    ...
# 60  DVN_DT_NTB_1        NaN            NaN            NaN    NaN
# 61  DVN_DT_NTB_1        NaN            NaN            NaN    NaN
# 62  DVN_DT_NTB_1        NaN            NaN            NaN    NaN
# 63  DVN_DT_NTB_1        NaN            NaN            NaN    NaN
# 64  DVN_DT_NTB_1        NaN            NaN            NaN    NaN
#
# [4357 rows x 7 columns]

# %%
professor = df[df.STT.notnull()]

dfObj = pd.DataFrame(professor, columns=['STT', 'Tên khoa học'])

df_remote = dfObj.drop_duplicates(subset='Tên khoa học', keep="first")


#professor.head(5)
#professor['Tên khoa học'].values

df_remote.info()
print('Shape:', df_remote.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-46159b24abc1> in <module>
# ----> 1 professor = df[df.STT.notnull()]
#       2
#       3 dfObj = pd.DataFrame(professor, columns=['STT', 'Tên khoa học'])
#       4
#       5 df_remote = dfObj.drop_duplicates(subset='Tên khoa học', keep="first")
#
# NameError: name 'df' is not defined

# %%
loai = pd.read_json('loai.json')
for element in df_remote['Tên khoa học'].values:
    #print(element.strip())
    check = False
    tmp = element.strip()
    for loai_element in loai.values:
        if element.strip()== loai_element[2].strip():
            check = True
            tmp = loai_element[2].strip() + "#" + str(loai_element[0])
    if check==False:
        tmp = element.strip() + "#0"
        print(element.strip())
# Out:
# Bacteriastrum hyalinum Lauder, 1864
# Actinocyclus ehrenbergii Ralfs in Pritchard, 1861
# Coscinodiscus astromphalus Ehr.
# Coscinodiscus spinosus Chin., 1965
# Cyclotella bodanica  Eulenstein ex Grunow, 1878
# Cyclotella striata (Kützing) Grunow, 1880
# Ethmodiscus sp.
# Stephanodiscus astraea Ehr. (Grun)
# Leptocylindrus danicus  Cleve, 1889
# Melosira distans  (Ehrenberg) Kützing, 1844
# Melosira nummuloides (Dilw.) Agardh, 1824
# Melosira varians C. Agardh, 1827
# Skeletonema costatum (Grev.) Cleve, 1873
# Stephanopyxis palmeriana (Greville) Grunow, 1884
# Coscinosira oestrupi Ostenfeld, 1900
# Lauderia borealis Gran, 1900
# Thalassiosira subtilis  (Ostenfeld) Gran, 1900
# Actinoptychus splendens (Shadbolt) Ralfs ex Pritchard, 1861
# Corethron criophilum Castracane, 1886
# Corethron hystrix Hensen, 1887
# Guinardia flaccida (Castracane) H. Peragallo, 1892
# Leptocylindrus danicus Cleve, 1873
# Rhizosolenia acuminatum (Perag.) Gran., 1892
# Rhizosolenia robusta Norman ex Ralfs in Pritchard, 1861
# Rhizosolenia stolterfothii Perag., 1888
# Rhizosolenia styliformis T. Brightwell, 1858
# Bacteriastrum comosum Pavillard, 1916
# Bacteriastrum delicatulum Cleve, 1897
# Bacteriastrum varians Lauder, 1864
# Chaetoceros abnomis Lauder
# Chaetoceros affinis Lauder, 1864
# Chaetoceros atlanticus Cleve, 1873
# Chaetoceros distantus Cleve, 1873
# Chaetoceros laciniosus F. Schütt, 1895
# Chaetoceros laevis G. Leuduger - Fortmorel, 1892
# Chaetoceros lauderia Ralfs, 1864
# Chaetoceros libenii Cleve
# Chaetoceros lorenzianus Grunow, 1863
# Chaetoceros pendulus Karsten, 1905
# Chaetoceros pseudocurvisetus Mangin, 1910
# Chaetoceros subtilis Cleve, 1896
# Chaetoceros weissflogii F. Schütt, 1905
# Attheya zachariasii Brun, 1894
# Biddulphia laevis Ehr.
# Biddulphia mobiliensis  (J. W. Bailey) Grunow, 1882
# Biddulphia pulchella Gray, 1821
# Ditylum sol Cleve, 1900
# Streptotheca thamesis Shrubsole
# Climacodium biconcavum  Cleve, 1897
# Eucampia cornuta (Cleve) Grunow in Van Heurck, 1883
# Asterionella japonica Cleve in Cleve & Möller, 1882
# Fragilaria bicapitata A. Mayer, 1917
# Fragilaria capucina Desm., 1825
# Synedra tabulata (Agadi) Kuetz.
# Synedra ulna  (Nitzsch) Ehrenberg, 1832
# Synedra utermoehlii Hust., 1932
# Thalassionema nitzschiades  (Grunow) Mereschkowsky, 1902
# Thalassiothrix frauenfeldii Cleve et Grun, 1880
# Thalassiothrix longissima Cleve et Grunow, 1880
# Cocconeis placentula var. euglypta (Ehrenb.) Grunow (1884)
# Amphipora alata (Ehrenb.) Kutz
# Cymbella lanceolata (C. Agardh) Kirchner, 1878
# Cymbella lata Grunow ex Cleve, 1894
# Gyrosigma balticum (Ehrenberg) Rabenhorst, 1853
# Gyrosigma distortum (W. Sm.) Cl.
# Gyrosigma scalproides var. eximium (Thwaites) P.T. Cleve, 1894
# Gyrosigma spenceri  (W. Smith) Griffith & Henfrey, 1856
# Navicula cancellata Donkin, 1872
# Navicula elegans W. Sm., 1853
# Navicula hasta Pant., 1892
# Pinnularia borealis Ehrenb., 1843
# Pleurosigma salinarum (Grunow) Grunow in Cleve & Grunow, 1880
# Nitzschia acicularis (Kützing) W. Smith, 1853
# Nitzschia lorenzziana Grunow in Cleve & Möller, 1879
# Nitzschia obtusa W. Smith, 1853
# Nitzschia ovalis H. J. Arnott 1880
# Nitzschia panduriformis W. Gregory, 1857
# Nitzschia paradoxa (J. F. Gmelin) Grunow in Cleve & Grunow, 1880
# Nitzschia sublinearis Hust., 1930
# Campilodiscus biangulatus Greville, 1862
# Surirella biseriata Brébisson in Brébisson & Godey, 1835
# Surirella capronii Brébisson ex F.Kitton
# Surirella tenera var. nervosa Hust.
# Scenedesmus bicaudatus var. bicaudatus Hort.
# Scenedesmus bijugatus (Turp.) Kuet. var. bijugatus
# Kirchneriella obesa (West) Sch. var. obese
# Actinastrum hantzchii Lagerh.
# Pediastrum duplex Meyen var. duplex
# Pediastrum simplex var. duodenarium  Rabenh
# Lagerheimia chodati Bernard
# Crucigenia tetrapedia (Kirchner) Kuntze, 1898
# Spirogyra decimina  (O. F. Müller) Dumortier, 1822
# Oedogonium crispum (Hassall) Wittrock, 1874
# Chaetomorpha capillaris (Kützing) Børgesen, 1925
# Rhizoclonium kerneri Stockmayer, 1890
# Rhizoclonium sp.
# Cladophora laetevirens Kutz.
# Enteromorpha intestinalis link
# Enteromorpha ralfsii Harvey.
# Ceratium arietinum Cleve
# Ceratium pentagonum Karsten
# Ceratium teres Jof.
# Ceratium tripos (O. F.) Muller.
# Peridinium pellucidum  (Bergh) Schütt, 1895
# Peridinium diabolus Cleve, 1900
# Dinophysis homunculi Stein, 1883
# Dinophysis tripos Gourret, 1883
# Trachelomonas cylindrical Ehrenberg, 1838
# Merismopedia elegans A.Braun ex Kützing, 1849
# Lyngbya aestuarii Liebm
# Alpheus crassimanus Heller, 1865
# Exopalaemon carinicauda Holthuis, 1950
# Metapenaeus ensis (de Haan, 1844)
# Parapenaeopsis tenella (Bate, 1888)
# Penaeus monodon (Fabricius, 1798)
# Acetes japonicus Kishinouye, 1905
# Acetes sp.
# Episesarma versicolor (Tweedie, 1940)
# Metaplax dentipes Chopra & Das, 1937
# Sesarma dehaani H.Milner - Edwards, 1853
# Sesarma plicata (Latreille, 1806)
# Nanosesarma batavicum (Moreira, 1903)
# Metopograpsus quadridentatus Stimpson, 1858
# Metopograpsus latifrons (White. 1847)
# Phylira heterograna Ortmann,1892
# Phylira globulosa
# Macrophthalmus definitus Adams & White, 1849
# Macrophthalmus erato De Man, 1887
# Macrophthalmus pacificus Dana, 1851
# Uca borealis Crane, 1975
# Ilyoplax ningpoensis Shen,1940
# Scopimera  tuberculata Stimpson, 1858
# Paracleistostoma depressum De Man, 1895
# Tmethypocoelis ceratophora (Koelbel, 1897)
# Calappa philargius (Linnaeus, 1758)
# Charybdis anisodon (de Haan, 1850)
# Portunus trituberculatus (Miers, 1876)
# Portunus sanguinolentus (Herbst, 1783)
# Scylla serrata Forskal, 1755
# Carinosquilla multicarinata (White, 1848)
# Oratosquilla oratoria (de Haan, 1844)
# Oratosquillina gravieri (Manning, 1978)
# Clithon sp.
# Neritina cornucopia Sowerby, 1832
# Neritina comunis (Quoy & Gaimard, 1832)
# Batillaria sp.
# Cerithidea cingulata (Gmeliin, 1790)
# Cerithidea djadjariensis (Martin, 1899)
# Telebralia sulcata (Born, 1778)
# Telebralia sp.
# Littoraria scabra (Linnaeus, 1758)
# Littoraria undulata (Gray, 1839)
# Assiminea lutea Adams, 1861
# Erato sp.
# Mammilla sp.
# Tanea sp.
# Buforaria rana (Linnaeus, 1758)
# Chicoreus brunneus (Link, 1807)
# Chicoreus capucinus (Lamark, 1822)
# Thais sp.
# Nassarius festivus (Powys, 1935)
# Zeuxis scalaris (A.Adams, 1852)
# Hemifusus crassicaudus (Philippi, 1848)
# Hemifusus tuba (Gmelin, 1781)
# Cassidula mustelina (Deshayes, 1830)
# Ellobium aurisjudae (Linnaeus, 1758)
# Melampus cristatus Pfeiffer, 1855
# Melanoides turberculatus (Muller, 1774)
# Anadara antiquata Linneaus, 1758
# Anadara subcrenata (Lienschke, 1869)
# Modiolus vaginus (Lamarck, 1819)
# Perna viridis (Linnaeus, 1758)
# Mytilus smaragdinus Chemnitz, 1785
# Barnea candida (Linnaeus, 1758)
# Bankia sauli (Wright, 1866)
# Isognomon ephippium (Linnaeus, 1758)
# Crassostrea rivularis (Gould 1861)
# Saccostrea cacullata (Born, 1778)
# Anomia chinensis Philippi, 1849
# Placuna placenta Linnaeus, 1758
# Eamesiella corrugata (Deshayes, 1855)
# Trapezium oblongum (Linnaeus, 1758)
# Dosinia japonica Reeve, 1856
# Sosinia nobilis Deshayes, 1853
# Gomphina aequilatera (Sowerby, 1825)
# Meretrix lusoria (Roding, 1798)
# Paphia lirata (Philippi, 1847)
# Paphia calophylla (Philippi, 1836)
# Mactra luzonica Reeve, 1854
# Mactra quadrangularis (Reeve, 1854)
# Psammotacea togata (Deshayes, 1855)
# Semele crenulata (Sowerby, 1966)
# Macroma incongrua (Martens, 1865)
# Tellina jedoensis Lischke, 1872
# Tellina rugosa Born, 1780
# Tellinides timorensis (Lamarck, 1818)
# Azorinus abbreviatus (Gould, 1861)
# Pharella javanica (Lamarck, 1818)
# Solen arcuatus Tchang & Hwang, 1964)
# Solen grandis (Dunker, 1861)
# Geloina coaxans (Gmelin, 1791)
# Austriella corrugata (Deshayes, 1843)
# Parapenaeopsis sculptilis (Heller, 1862)
# Penaeus semisulcatus (de Hann, 1850)
# Episesarma chengtongense (Ser. & Soh., 1967)
# Ocypode stimpsoni Ortmann, 1897
# Uca arcuta (Stimpson, 1858)
# Ilyoplax orientalis(De Man, 1888)
# Ilyoplax formosensis Rathbun, 1921
# Captandrium elongatumRathbun, 1931
# Paracleistostoma cristaum De Man, 1895
# Matuta lunaris Alcock, 1896
# Scylla paramamosain Estampador, 1949
# Anchisquilla fasciata (de Haan, 1844)
# Planktoniella sol (Wallich) Schütt, 1892
# Melosira dubia Kutz., 1844
# Actinoptychus triglingulatus A. Schmidt in Schmidt et al., 1874
# Rhizosolenia alata Brightwell (1858)
# Rhizosolenia delicatula Cleve, 1900
# Chaetoceros crinitus F. Schütt, 1895
# Chaetoceros pelagicus Cleve
# Biddulphia regia  (Schultze) Ostenfeld, 1908
# Climacodium frauenfeldinum Grunow
# Eucampia zoodiacus Ehr., 1839
# Synedra acus Kuetz
# Cymbella turmida  (Brébisson) van Heurck, 1880
# Gyrosigma acuminatum var. lacustre  (W. Smith) Cleve-Euler, 1952
# Navicula pusilla var. lanceolata Grunow in Cleve & Grunow, 1880
# Nitzschia closterium (Ehrenberg) W. Smith, 1853
# Nitzschia longissima  (Brébisson) Ralfs in Pritchard, 1861
# Nitzschia pungens Grunow ex Cleve, 1897
# Nitzschia seriata Cl., 1883
# Nitzschia sigma (Kützing) W. Smith, 1853
# Staurastrum gracile  Ralfs ex Ralfs, 1848
# Chaetomorpha linum (O. F. Müller) Kützing, 1845
# Merismopedia punctata Meyen, 1839
# Prionospio pinnata Ehlers, 1901
# Acrocalanus gibber Giesbrecht, 1888
# Calocalanus pavo (Dana, 1852)
# Calocalanus styliremis Giesbrecht, 1888
# Candacia truncata (Dana, 1849)
# Acartia pacifica Steuer, 1915
# Acartia discaudata (Giesbrecht, 1882)
# Clausocalanus arcuicornis (Dana, 1849)
# Eurytemora pacifica Sato, 1913
# Centropages furcatus (Dana, 1849)
# Centropages sinensis Chen & Zhang, 1965
# Centropages tenuiremis Thompson & Scott, 1903
# Sinocalanus tenellus (Kikuchi, 1928)
# Sinocalanus laevidactylus Shen et Tai, 1964
# Corycaeus asiaticus Dahl F., 1894
# Corycaeus dahli Tanaka, 1957
# Euchaeta longicornis Giesbrecht, 1888
# Euchaeta sp.
# Pseudodiaptomus marinus Sato, 1913
# Schmackeria speciosa Dang, 1967
# Schmackeria spatulata Shen et Tai, 1964
# Schmackeria sp.
# Temora turbinata Wolfenden , 1911
# Lucicutia flavicornis (Claus, 1863)
# Labidocera detruncata (Dana, 1849)
# Pontella chierchiae Giesbrecht, 1889
# Pontellina plumata (Dana, 1849)
# Tortanus derjugini Smirnov, 1935
# Canthocalanus pauper (Giesbrecht, 1888)
# Eodiaptomus draconisignivomi Brehm, 1952
# Neodiaptomus yangtsekiangensis Mashiko, 1951
# Oithona nana Giesbrecht, 1893
# Oithona rigida Giesbrecht, 1896
# Oithona tenuis Rosendorn, 1917
# Oithona sp.
# Thermocyclops hyalinus (Rehberg, 1880)
# Microsetella norvegica (Boeck, 1846)
# Stella gracilis Dana, 1847
# Conchoecissa imbricata (Brady, 1880)
# Clithon retropicta (v. Martens, 1879)
# Cerithium subscalatum Pilsbry, 1904
# Littoraria melanostoma (Gray, 1839)
# Assiminea brevicula (Pfeiffer,1854)
# Melampus sincaporensis Pfeiffer, 1855
# Modiolus philippinarum (Hanley, 1843)
# Xenostrobus atrata (Lischke, 1871)
# Mytilus smaragdinus Chemnitz, 1785
# Teredo manni (Wright, 1866)
# Isognomon ephippium (Linnaeus, 1758)
# Saccostrea glomerata (Gould, 1850)
# Enignomia aenigmatica (Holten, 1803)
# Trapezium sublaevigatum (Lamarck, 1819)
# Cyclina sinensis (Gmelin, 1791)
# Dosinia laminata (Reeve, 1850)
# Merisca capsoides (Lamarck, 1818)
# Sinonovacula constricta (Lamarck, 1818)
# Onuphis sp.
# Candacia pectinata Brady, 1878
# Acartia danae Giesbrecht, 1889
# Aetideus armatus (Boeck, 1872)
# Clausocalanus furcatus (Brady, 1883)
# Scolecithricella longispinosa Chen & Zhang, 1965
# Temora turbinata (Dana, 1849)
# Centropages orsini Giesbrecht, 1889
# Corycaeus andrewsi Farran, 1911
# Corycaeus erythraeus Cleve, 1904
# Corycaeus longistylus Dana, 1849
# Pseudodiaptomus bulbiferus (Rose, 1957)
# Schmackeria bulbosa Shen et Tai, 1964
# Schmackeria curvilobata Dang, 1967
# Lucicutia ovalis (Giesbrecht, 1889)
# Calanopia elliptica A. Scott, 1902
# Calanopia minor Scott A., 1902
# Labidocera euchaeta Giesbrecht, 1889
# Labidocera pavo Giesbrecht, 1889
# Pontellopsis yamadae Mori, 1937
# Tortanus forcipatus Giesbrecht, 1889
# Diaptomus sp.
# Mongolodiaptomus formosanus Kiefer, 1937
# Undinula vulgaris (Dana, 1849)
# Allodiaptomus pectinidactylus Shen et Tai, 1964
# Heliodiaptomus serratus Shen et Tai, 1962
# Neodiaptomus handeli (Brehm, 1921)
# Oithona plumifera Baird, 1843
# Oithona simplex Farran, 1913
# Oithona attenuata Farran, 1913
# Eucyclops serrulatus (Fischer, 1851)
# Paracyclops fimbriatus (Fischer, 1853)
# Tropocyclops prasinus (Fischer, 1860)
# Thermocyclops minutus (Lowndes, 1934)
# Cyclotella comta (Ehrenberg) Kützing, 1849
# Biddulphia sinensis Greville, 1866
# Fragilaria virescens Rafls., 1843
# Navicula placentula (Ehrenberg) Kützing, 1844
# Chaetomorpha indica (Kützing) Kützing, 1849
# Enteromorpha clathrata (Roth) Greville.
# Ceratium breve Schroder.
# Ceratium strictum Kof.
# Oscillatoria limosa J. Ag.
# Spirulina tenuissima Kuetz.
# Littoraria sp.
# Ellobium chinensis (Pfeiffer, 1854)
# Anadara cornea (Reeve, 1844)
# Anadara granosa (Linnaeus, 1758)
# Sanguinolaria diphos (Linnaeus, 1771)
# Glaucomya chinensis Gray, 1901
# Solen gouldi (Conrad, 1867)
# Acrocalanus gracilis Giesbrecht, 1888
# Aetideus sp.
# Centropages dorsispinatus Thompson IC & Scott A., 1903
# Centropages gracilis (Dana, 1849)
# Sinocalanus mystrophorus Burckhardt, 1913
# Corycaeus agilis Dana, 1849
# Corycaeus sp.
# Schmackeria gordioides Brehm, 1952
# Lucicutia grandis (Giesbrecht, 1895)
# Calanopia thompsoni Scott A., 1909
# Labidocera biinnata Tanaka, 1936
# Labidocera minuta Giesbrecht, 1889
# Vietodiaptomus hatinhensis Dang, 1977
# Allodiaptomus gladiolus Shen et Lee, 1963
# Limnoithona sinensis (Burckhardt, 1912)
# Oithona aruensis Früchtl, 1923
# Oithona fallax Farran, 1913
# Eucyclops speratus (Lilljeborg, 1901)
# Tropocyclops sp.
# Alpheus malabaricus Fabricius 1775
# Metapenaeus affinis (Milne - Edwards, 1837)
# Nanosesarma minuta (De Man) 1887
# Macrophthalmus dilatatus
# Ocypode ceratophthalmus (Pallas, 1772)
# Baruna trigranulum(Dai & Song, 1986)
# Charybdis affinis Dana, 1852
# Squilla nepa (Latreille, 1828)
# Lutjanus johnii (Bloch, 1792)
# Paracalanus aculeatus Giesbrecht, 1888
# Calocalanus plumulosus (Claus, 1863)
# Acartia erythraea Giesbrecht, 1889
# Acartia sp.
# Corycaeus agilis Dana, 1849
# Corycaeus gibbulus Giesbrecht, 1891
# Euchaeta concinna Dana, 1849
# Oncaea venusta Philippi, 1843
# Oncaea sp.
# Ectocyclops phaleratus (Koch, 1838)
# Thermocyclops taihokuensis (Harada,1931)
# Cyclotella kuetzingina Thwaites, 1848
# Chaetoceros contrictus  Gran, 1897
# Scenedesmus bijugatus var. alternans (Reinsch) Hang
# Pediastrum simplex  Lemm. var. simplex
# Clithon corona (Linnaeus, 1758)
# Pliarcularia pullus (Linneaus, 1758)
# Zeuxis dorsatus (Roding, 1798)
# Nitidotellina minuta (Lischke, 1877)
# Metapenaeus joyneri (Miers, 1880)
# Parapenaeopsis hardwicklii (Miers, 1878)
# Eriocheir sinensis H.Milne - Edwards, 1853
# Metaplax longipes
# Uca flammula Crane, 1975

# %%
df_demo = pd.DataFrame({'Data': [10, 20, 30, 20, 15, 30, 45]})
append_df_to_excel("BIỂU MẪU - BIỂU PHÂN TÍCH MẪU CÁ#2065.xlsx",df_demo,"LoaiDaDangSinhHoc", 3)
